# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

import pandas as pd
pd.set_option('display.max_columns', None)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
acc = pd.read_csv('./use_data/result/mart/TB_ACC_RST_FST_TRY.csv')
vio = pd.read_csv('./use_data/result/mart/TB_VIO_RST_FST_TRY.csv')
